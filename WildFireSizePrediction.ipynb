# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import sqlite3
import altair as alt
 
pd.set_option('display.float_format', lambda x: '%.2f' % x)
conn = sqlite3.connect('/content/drive/MyDrive/wildfirelinear/FPA_FOD_20170508.sqlite')
fires = pd.read_sql("""SELECT * FROM fires""", con=conn)

# %%
fires
# Out:
#          OBJECTID  ...                                              Shape
# 0               1  ...  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 1               2  ...  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 2               3  ...  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 3               4  ...  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4               5  ...  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
# ...           ...  ...                                                ...
# 1880460   1880461  ...  b'\x00\x01\xad\x10\x00\x00P\xb8\x1e\x85\xeb\x9...
# 1880461   1880462  ...  b'\x00\x01\xad\x10\x00\x00\x00\x80\xbe\x88\x11...
# 1880462   1880463  ...  b'\x00\x01\xad\x10\x00\x00\x00\x80\xbe\x88\x11...
# 1880463   1880464  ...  b'\x00\x01\xad\x10\x00\x00x\xba_\xaa~9^\xc0\xb...
# 1880464   1880465  ...  b'\x00\x01\xad\x10\x00\x00\x1c\xa7\xe8H.5]\xc0...
#
# [1880465 rows x 39 columns]

# %%
x = fires[['DISCOVERY_DOY','FIRE_YEAR','LATITUDE','LONGITUDE']]
x
# Out:
#          DISCOVERY_DOY  FIRE_YEAR  LATITUDE  LONGITUDE
# 0                   33       2005     40.04    -121.01
# 1                  133       2004     38.93    -120.40
# 2                  152       2004     38.98    -120.74
# 3                  180       2004     38.56    -119.91
# 4                  180       2004     38.56    -119.93
# ...                ...        ...       ...        ...
# 1880460            269       2015     40.48    -122.39
# 1880461            278       2015     37.62    -120.94
# 1880462            122       2015     37.62    -120.94
# 1880463            287       2015     37.67    -120.90
# 1880464             73       2015     34.26    -116.83
#
# [1880465 rows x 4 columns]

# %%
y = fires['FIRE_SIZE_CLASS']
y
# Out:
# 0          A
# 1          A
# 2          A
# 3          A
# 4          A
#           ..
# 1880460    A
# 1880461    A
# 1880462    A
# 1880463    B
# 1880464    A
# Name: FIRE_SIZE_CLASS, Length: 1880465, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.5594600271741298

# %%
a = model.score(X_train, y_train)
a
# Out:
# 0.5605235938983177

# %%
b = model.score(X_test, y_test)
b
# Out:
# 0.5594600271741298

# %%
import matplotlib.pyplot as plt
plt.bar(["train","test"], [a, b])
# Out:
# <BarContainer object of 2 artists>
